# %% [markdown]
# **Содержание темы**
# 1. [Теория](https://colab.research.google.com/drive/1mgQaPN1eqhzNpTYTqbbXZHmolI7d2yll?usp=sharing)
#
# 2. [Практика 1](https://colab.research.google.com/drive/1dApswu6lfXEWfPl9ZgTspfFIneWGQIOq?usp=sharing)
#
# 3. Практика 2

# %% [markdown]
# Привет!
#
# Это второй из двух практических ноутбуков по теме **Автокодировщики**.
#
# Здесь вы:
# * закрепите знания, полученные в предыдущей практике;
# * построите и обучите модель автокодировщика на изображениях с лицами людей;
# * напишете алгоритм генерации шума на этих изображениях;
# * узнаете, как на практике модель удаляет шум с изображений;
# * построите и обучите модель для распознавания мошеннических транзакций.

# %% [markdown]
# # Автокодировщики: примеры решения прикладных задач

# %% [markdown]
# В этом разделе вы напишете и обучите модель автокодировщика, удаляющего шум с изображений.

# %% [markdown]
# ## Импорт библиотек

# %%
# Работа с массивами данных
import numpy as np

# Работа с таблицами
import pandas as pd

# Основные слои
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization

# Оптимизаторы для обучения модели
from tensorflow.keras.optimizers import Adam

# Функции-утилиты для работы с категориальными данными
from tensorflow.keras import utils

# Загрузка сохраненной модели
from tensorflow.keras.models import load_model

# Готовые датасеты
from tensorflow.keras.datasets import mnist, fashion_mnist

# Коллбэки для выдачи информации в процессе обучения
from tensorflow.keras.callbacks import LambdaCallback

# класс для использования Functional API
from tensorflow.keras import Model

# Отрисовка изображения
from tensorflow.keras.preprocessing import image

# Разбиение на тренировочную и тестовую выборки
from sklearn.model_selection import train_test_split

# Функция среднеквадратической ошибки для расчетов вручную
from sklearn.metrics import mean_squared_error

# Загрузка датасетов из облака google
import gdown

# Функции операционной системы
import os

# Работа со временем
import time

# Отрисовка графиков
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747953627.735454   13669 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747953627.744458   13669 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Удаление шума на изображениях лиц
#
# В данном разделе решается задача удаления шума с изображений.

# %% [markdown]
# ### Архитектура автокодировщика
#
# Рассмотрите функцию создания модели НС. В данном случае вы практически все знаете.
# Есть только одна особенность: вместо **MaxPooling** применен параметр **strides** слоя
# **Conv2D**, который отвечает за то, насколько уменьшится изображение. Наши эксперименты показали, что такая замена в данной задаче дает лучший результат (хотя, возможно, вы сможете создать архитектуру лучше нашей, но с MaxPooling).

# %%
# Функция сборки свёрточного автокодировщика
def create_base_ae(in_shape):

  # Входной слой
  inputs = Input(in_shape)

  # Энкодер
  # ---------------------------------------------------------------

  # 3 блока свертки перед сжатием
  x = Conv2D(12, 3, padding='same', activation='relu')(inputs)
  x = BatchNormalization()(x)

  # используем разрежение (dilation_rate) для выявления мелких деталей изображения
  x = Conv2D(24, 3, dilation_rate=2, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(48, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  # Сжатие 1
  x = Conv2D(96, 3, strides=2, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(96, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  # Сжатие 2
  x = Conv2D(128, 3, strides=2, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(256, 3, padding='same', activation='relu')(x)

  # Скрытое пространство
  z = BatchNormalization()(x)

  # Декодер
  # ---------------------------------------------------------------
  # Расширение 2
  x = Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(z)
  x = BatchNormalization()(x)

  x = Conv2D(128, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  # Расширение 1
  x = Conv2DTranspose(96, 3, strides=2, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(48, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(24, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(8, 3, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)

  # финальный слой свертки, выход модели
  outputs = Conv2D(1, 2, dilation_rate=2, padding='same', activation='sigmoid')(x)

  # Сборка модели. На входе оригинальное изображение, на выходе - сжатое-восстановленное
  model = Model(inputs, outputs)

  # компиляция модели
  model.compile(optimizer=Adam(1e-4),
                loss='mse')

  return model

# %% [markdown]
# Скорость экспериментально выбрана равной $10^{-4}$ (в Python пишется как `1e-4`) как оптимальный выбор между качеством результата и времени обучения. При более высокой скорости модель в некоторый момент момент начинает "скакать" около более оптимальных весов, но не стремиться к ним. А при более низкой скорости модель обучается слишком медленно.

# %% [markdown]
# ### Сервисные функции

# %%
# Функция последовательного вывода нескольких изображений для сравнения
def plot_images(target_images, noised_images, pred, shape=None, n=4):
    if shape is None:                               # Автоопределение формы данных
        shape = target_images.shape[1:3]                   # форма изображения

    plt.figure(figsize=(n*4, n*4), dpi=100)                     # Размер полотна
    plt.subplots_adjust(hspace=0.2, wspace=0.001)

    for i in range(0, n):                              # Повтор n раз:
        index = np.random.randint(0, pred.shape[0]) # Выбор случайного индекса

        # Показ картинки с индексом index из оригинального набора
        ax = plt.subplot(n, 4, 4*i + 1)               # Картинка располагается в верхнем ряду
        plt.imshow(target_images[index].reshape(shape), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.set_title('Оригинал')

        # Показ шумовой картинки с тем же индексом
        ax = plt.subplot(n, 4, 4*i + 2)           # Картинка располагается в среднем ряду
        plt.imshow(noised_images[index].reshape(shape), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.set_title('Зашумлённое изображение')

        # Показ картинки с тем же индексом из предсказания автокодировщика
        ax = plt.subplot(n, 4, 4*i + 3)           # Картинка располагается в нижнем ряду
        plt.imshow(pred[index].reshape(shape), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.set_title('Предсказание')

        # Показ разницы предсказания и зашумленной картинки
        ax = plt.subplot(n, 4, 4*i + 4)           # Картинка располагается в нижнем ряду
        plt.imshow(noised_images[index].reshape(shape) - pred[index].reshape(shape),
                   cmap='gray', vmin=0, vmax=1)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.set_title('Извлечённый шум')

    plt.show()

# %% [markdown]
# ### Определение оптимального порога

# %%
# Функция поиска оптимального порога
# На входе - mse на верном наборе и наборе выбросов,
# количество шагов порога и указание, показывать график или нет
def find_optimal_threshold(err_true, err_wrong, points=1000, factor = 2., show=True):
    # Сетка порогов между средней и кратной максимальной ошибками с малым шагом
    thresholds = np.linspace(err_true.mean(), factor * err_true.max(), points)

    # Массив значений ошибок для каждого значения порога
    errors_true = np.empty(thresholds.shape)
    errors_wrong = np.empty(thresholds.shape)
    errors_overall = np.empty(thresholds.shape)

    # Расчет ошибок на верных и неверных данных, общей ошибки
    # для каждого порога, и занесение ошибок в массивы
    for i in range(thresholds.shape[0]):
        errors_true[i] = 1 - (err_true < thresholds[i]).mean()
        errors_wrong[i] = (err_wrong < thresholds[i]).mean()
        errors_overall[i] = errors_true[i] + errors_wrong[i]

    # Определение индекса оптимального порога по минимальной общей ошибке
    optimal_i = np.argmin(errors_overall)

    # Если требуется, вывод картинки и статистик
    if show:
        plt.figure(figsize=(14,7))
        plt.plot(thresholds, errors_true, label='На верных данных')
        plt.plot(thresholds, errors_wrong, label='На выбросах')
        plt.plot(thresholds, errors_overall, label='Общая ошибка')
        plt.plot(thresholds[optimal_i], errors_overall[optimal_i], 'ro')
        plt.xlabel('Порог')
        plt.ylabel('Ошибки')
        plt.legend()
        plt.title('График ошибок при разных порогах')
        plt.show()

        print('Оптимальный порог: {:.4f}'.format(thresholds[optimal_i]))
        print('Распознано как норма на верных данных: {:.2f}%'.format(100 * (1 - errors_true[optimal_i])))
        print('Распознано как норма на выбросах     : {:.2f}%'.format(100 * errors_wrong[optimal_i]))
        print('Суммарная ошибка: {:.2f}%'.format(100 * errors_overall[optimal_i]))

    # Возврат оптимальных значений: индекс, значение порога и все ошибки
    return optimal_i, \
           thresholds[optimal_i], \
           errors_true[optimal_i], \
           errors_wrong[optimal_i], \
           errors_overall[optimal_i]

# %% [markdown]
# ### Загрузка датасета и подготовка данных

# %% [markdown]
# В первую очередь загрузите датасет по ссылке:

# %%
# Загрузка датасета из облака
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l13/facez.zip', None, quiet=False)
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/aiueducation/Content/base/l13/facez.zip
# To: /home/aledonio/global/Занятие 9/Практика/facez.zip
# 100%|██████████| 444M/444M [01:19<00:00, 5.60MB/s]
# 'facez.zip'

# %% [markdown]
# Разархивируйте его командой `!unzip` в папку **faces**:

# %%
# Распаковка архива в папку faces
# !unzip -qo facez.zip -d faces/

# %% [markdown]
# Рассмотрите константы, которые в дальнейшем вам потребуются.

# %%
# Настройка констант
IMG_DIR = 'faces'                         # Папка с изображениями
IMG_HEIGHT = 112                          # Высота изображений
IMG_WIDTH = 80                            # Ширина избражений
VAL_SPLIT = 0.05                          # Доля проверочной выборки от основного набора

# %% [markdown]
# Чтобы получить
# полноценный датасет, загрузите изображения и объедините их в один список. Для этого
# напишите функцию, в которой вы создадите пустой список для изображений. Затем
# пройдитесь в цикле по всем изображениям в папке и добавьте их в список. Подробнее:
#
# * `os.path.join(folder, img)` – объединяете путь к файлу из двух частей,
# пути к папке и название файла;
# * `target_size=(height, width)` – новая размерность изображений;
# * `color_mode='grayscale'` – к какой цветовой гамме привести изображения, в
# данном случае – к черно-белому формату;
# * `image.load_img()` – подгружаете изображения;
# * `image.img_to_array()` – превращаете рисунок в массив данных.
#
# На выходе функции будет массив с изображениями.

# %%
# функция загрузки изображений
# На входе: имя папки с изображениями, высота и ширина, к которым будут приведены изображения
def load_images(folder, height, width):
    image_list = []                       # Список для изображений
    for img in os.listdir(folder):        # Перебор по именам файлов в папке
        # Добавление в список изображения в виде массива,
        # в заданных размерах и в оттенках серого
        image_list.append(image.img_to_array(image.load_img(os.path.join(folder, img),
                                                             target_size=(height, width),
                                                             color_mode='grayscale')))
    # Возврат массива-результата
    return np.array(image_list)

# %% [markdown]
# Засечём время и посмотрим за сколько все наши изображения подгрузятся. Выведем результат на экран.

# %%
# Загрузка датасета в память
cur_time = time.time()
data_faces = load_images(IMG_DIR, IMG_HEIGHT, IMG_WIDTH)
print(f'Время загрузки: {round(time.time()-cur_time)} с.')
# Out:
# Время загрузки: 7 с.

# %% [markdown]
# Не забудьте нормализовать данные и привести их в диапазон от 0 до 1.

# %%
# Сжатие диапазона [0, 255] значений к диапазону [0, 1]
data_faces = data_faces.astype('float32') / 255.

# %% [markdown]
# Разделите датасет на тренировочные и тестовые целевые изображение функцией `train_test_split`.

# %%
# Разбиение на обучающие и проверочные целевые изображения
y_train, y_test = train_test_split(data_faces, test_size=VAL_SPLIT)

# %% [markdown]
# > Данная задача нестандартна тем, что весь исходный датасет – это целевые изображения. А исходных данных пока нет, потому что исходные данные – это те же целевые изображенния, но с шумом, который пока не сгенерирован.

# %%
# Размерность выборки
print(y_train.shape, y_test.shape, sep='\n')
# Out:
# (4767, 112, 80, 1)
# (251, 112, 80, 1)

# %% [markdown]
# Выборка получается небольшой. Но для демонстрации этого достаточно.
#
# Выведите случайное изображение на экран.<br>
# Для этого можно сначала выбрать случайный индекс, по которому потом мы получим изображение.

# %%
# Выбор индекса случайного изображения из тренировочных
random_index = np.random.randint(0, y_train.shape[0])

# %% [markdown]
# Для визуализации можно использовать `plt`. <br>
# При одноканальных изображениях этот фреймворк требует убирать уже лишнюю ось каналов, так как она всего одна, поэтому избыточна. Это можно сделать функцией `.squeeze()`.

# %%
# Удаление последней оси для корректной работы plt
random_img = y_train[random_index].squeeze(axis=-1)

# %%
# Вывод примера в черно-белом формате
plt.imshow(random_img, cmap='gray')
plt.show()

# %% [markdown]
# ### Шум

# %% [markdown]
# Теперь сгенерируйте шумовые картинки.
#
# Для этого можно использовать функцию `np.random.standard_normal`. Функция генерирует случайные значения согласно стандартному нормальному распределению.
#
# Случайные значения стандартного распределения нам не очень подходят – слишком большой разброс и слишком много отрицательных чисел. Поэтому сжимаем шум в 30 раз и сдвигаем на 0.5.

# %%
# генерируем тензор случайных значения сразу равных по количеству и форме наших данных
train_noise = np.random.standard_normal(y_train.shape)/30 + .5
test_noise = np.random.standard_normal(y_test.shape)/30 + .5

# %% [markdown]
# Теперь на каждый пиксель каждого тренировочного и тестового изображения есть случайное (шумовое) значение. Чтобы лучше понять, что это за числа, построим гистограмму.

# %%
print("Число случайных значений на гистограмме:", train_noise.reshape(-1).shape)

plt.figure(dpi=100)
_ = plt.hist(train_noise.reshape(-1), bins=100)
plt.ylabel('Число случайных значений на интервале')
plt.xlabel('Числовые интервалы')
plt.title("Гистограмма нормального распределения")
plt.show()
# Out:
# Число случайных значений на гистограмме: (42712320,)

# %% [markdown]
# Ось случайно сгенерированных чисел делится на 100 интервалов (число интервалов может быть любым). Далее каждому интервалу ставится в соответствие столб (вертикальная ось). Высота этого столба – это количество случайных чисел, попавших в этот интервал.

# %%
# создадим зашумленные изображения
X_train = y_train + train_noise
X_test = y_test + test_noise

# %% [markdown]
# Отобразите случайное оригинальное изображение, прибавляемый к нему шум и зашумленное изображение.

# %%
# Создаем полотно
fig = plt.figure(figsize=(15, 5))

# Выбираем индекс изображения случайно
choice = np.random.randint(0, X_train.shape[0])

# Создаем области ax для отрисовки изображений
ax_1 = fig.add_subplot(1, 3, 1)
ax_2 = fig.add_subplot(1, 3, 2)
ax_3 = fig.add_subplot(1, 3, 3)

# Отрисовываем изображения
ax_1.imshow(y_train[choice].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')
ax_2.imshow(train_noise[choice].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray', vmin=0, vmax=1)
ax_3.imshow(X_train[choice].reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')

# Подписываем
ax_1.set_title('Оригинальное изображение')
ax_2.set_title('Шум')
ax_3.set_title('Зашумленное изображение')

ax_1.text(IMG_WIDTH+10, IMG_HEIGHT/2, '+', fontsize=40)
ax_2.text(IMG_WIDTH+10, IMG_HEIGHT/2, '=', fontsize=40)

# прописываем пустую инструкцию, иначе выведется значение, возвращенное ax_2 (которое нам не нужно)
pass

# %% [markdown]
# Таким образом мы получили к каждой оригинальной картинке зашумленный аналог. Теперь создадим автокодировщик, пытающийся отчистить этот шум, вернув картинку к исходному состоянию.

# %% [markdown]
# ### Создание и обучение автокодировщика

# %% [markdown]
# Создайте и обучите НС. Процесс ничем не отличается от того, что вы рассмотрели в первой практике.

# %%
# Создание автокодировщика
ae_faces = create_base_ae(X_train.shape[1:])
# Out:
# I0000 00:00:1747676500.122629  416065 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6102 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# Отображение модели
utils.plot_model(ae_faces, show_shapes=True, dpi=70)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# Обучение модели на датасете лиц
ae_faces.fit(X_train, y_train,
             epochs=50,
             batch_size=8,
             validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747676504.647595  416378 service.cc:152] XLA service 0x7f5c200324b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747676504.647617  416378 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 2060 SUPER, Compute Capability 7.5
# 2025-05-19 20:41:44.740996: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747676505.413523  416378 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-19 20:41:45.709675: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[8,12,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,112,80]{3,2,1,0} %bitcast.10703, f32[12,1,3,3]{3,2,1,0} %bitcast.10710, f32[12]{0} %bitcast.13173), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:45.748323: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[32,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,12,58,42]{3,2,1,0} %bitcast.10783, f32[24,12,3,3]{3,2,1,0} %bitcast.10790, f32[24]{0} %bitcast.13399), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:46.228288: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[8,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,56,40]{3,2,1,0} %bitcast.14015, f32[96,96,3,3]{3,2,1,0} %bitcast.11015, f32[96]{0} %bitcast.14075), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:46.576410: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[8,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,28,20]{3,2,1,0} %bitcast.14465, f32[256,128,3,3]{3,2,1,0} %bitcast.11158, f32[256]{0} %bitcast.14525), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:47.547632: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[8,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,56,40]{3,2,1,0} %bitcast.14916, f32[128,128,3,3]{3,2,1,0} %bitcast.11302, f32[128]{0} %bitcast.14976), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:27.564854: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv %cudnn-conv-bias-activation.45 = (f32[8,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,56,40]{3,2,1,0} %bitcast.14916, f32[128,128,3,3]{3,2,1,0} %bitcast.11302, f32[128]{0} %bitcast.14976), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:42:27.581041: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.891829023s
# Trying algorithm eng18{k2=2,k4=2,k5=0,k6=0,k7=0} for conv %cudnn-conv-bias-activation.45 = (f32[8,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,56,40]{3,2,1,0} %bitcast.14916, f32[128,128,3,3]{3,2,1,0} %bitcast.11302, f32[128]{0} %bitcast.14976), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:41:47.992691: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.46 = (f32[8,48,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,112,80]{3,2,1,0} %bitcast.15366, f32[48,96,3,3]{3,2,1,0} %bitcast.11446, f32[48]{0} %bitcast.15426), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:48.540237: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.47 = (f32[8,24,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,48,112,80]{3,2,1,0} %bitcast.15590, f32[24,48,3,3]{3,2,1,0} %bitcast.11517, f32[24]{0} %bitcast.15650), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:41:48.787342: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.48 = (f32[8,8,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,24,112,80]{3,2,1,0} %bitcast.15814, f32[8,24,3,3]{3,2,1,0} %bitcast.11588, f32[8]{0} %bitcast.15874), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:32.566258: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng1{k2=8,k3=0} for conv %cudnn-conv-bw-filter.23 = (f32[128,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,57,41]{3,2,1,0} %bitcast.14241, f32[8,128,28,20]{3,2,1,0} %bitcast.14305), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1/conv2d_5_1/convolution/Conv2DBackpropFilter" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:42:32.583449: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.870125772s
# Trying algorithm eng1{k2=8,k3=0} for conv %cudnn-conv-bw-filter.23 = (f32[128,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,57,41]{3,2,1,0} %bitcast.14241, f32[8,128,28,20]{3,2,1,0} %bitcast.14305), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1/conv2d_5_1/convolution/Conv2DBackpropFilter" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#   3/596 ━━━━━━━━━━━━━━━━━━━━ 32s 56ms/step - loss: 0.1228
# I0000 00:00:1747676518.676349  416378 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 504/596 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - loss: 0.0201
# 2025-05-19 20:42:27.712745: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[7,12,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,1,112,80]{3,2,1,0} %bitcast.10703, f32[12,1,3,3]{3,2,1,0} %bitcast.10710, f32[12]{0} %bitcast.13173), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:27.744318: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[28,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[28,12,58,42]{3,2,1,0} %bitcast.10783, f32[24,12,3,3]{3,2,1,0} %bitcast.10790, f32[24]{0} %bitcast.13399), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:43:07.622805: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng19{k2=2,k4=2,k5=3,k6=2,k7=1} for conv %cudnn-conv-bias-activation.39 = (f32[28,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[28,12,58,42]{3,2,1,0} %bitcast.10783, f32[24,12,3,3]{3,2,1,0} %bitcast.10790, f32[24]{0} %bitcast.13399), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:43:07.623527: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.854883391s
# Trying algorithm eng19{k2=2,k4=2,k5=3,k6=2,k7=1} for conv %cudnn-conv-bias-activation.39 = (f32[28,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[28,12,58,42]{3,2,1,0} %bitcast.10783, f32[24,12,3,3]{3,2,1,0} %bitcast.10790, f32[24]{0} %bitcast.13399), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:42:27.537888: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[7,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,96,56,40]{3,2,1,0} %bitcast.14015, f32[96,96,3,3]{3,2,1,0} %bitcast.11015, f32[96]{0} %bitcast.14075), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:27.841933: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[7,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,128,28,20]{3,2,1,0} %bitcast.14465, f32[256,128,3,3]{3,2,1,0} %bitcast.11158, f32[256]{0} %bitcast.14525), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:28.852800: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[7,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,128,56,40]{3,2,1,0} %bitcast.14916, f32[128,128,3,3]{3,2,1,0} %bitcast.11302, f32[128]{0} %bitcast.14976), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:29.931460: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.46 = (f32[7,48,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,96,112,80]{3,2,1,0} %bitcast.15366, f32[48,96,3,3]{3,2,1,0} %bitcast.11446, f32[48]{0} %bitcast.15426), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:30.437048: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.47 = (f32[7,24,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,48,112,80]{3,2,1,0} %bitcast.15590, f32[24,48,3,3]{3,2,1,0} %bitcast.11517, f32[24]{0} %bitcast.15650), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:30.806947: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.48 = (f32[7,8,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,24,112,80]{3,2,1,0} %bitcast.15814, f32[8,24,3,3]{3,2,1,0} %bitcast.11588, f32[8]{0} %bitcast.15874), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:43:12.635939: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng9{k2=0,k4=2,k5=1,k6=0,k7=0} for conv %cudnn-conv-bw-input.24 = (f32[7,128,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,256,28,20]{3,2,1,0} %bitcast.14529, f32[256,128,3,3]{3,2,1,0} %bitcast.11158), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_6_1/convolution/Conv2DBackpropInput" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:43:12.636847: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.8651533s
# Trying algorithm eng9{k2=0,k4=2,k5=1,k6=0,k7=0} for conv %cudnn-conv-bw-input.24 = (f32[7,128,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,256,28,20]{3,2,1,0} %bitcast.14529, f32[256,128,3,3]{3,2,1,0} %bitcast.11158), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_6_1/convolution/Conv2DBackpropInput" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 20:42:40.503417: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[8,12,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,112,80]{3,2,1,0} %bitcast.1175, f32[12,1,3,3]{3,2,1,0} %bitcast.1182, f32[12]{0} %bitcast.1184), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:40.533935: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[32,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,12,58,42]{3,2,1,0} %bitcast.1223, f32[24,12,3,3]{3,2,1,0} %bitcast.1230, f32[24]{0} %bitcast.1232), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:40.871700: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[8,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,56,40]{3,2,1,0} %bitcast.1344, f32[96,96,3,3]{3,2,1,0} %bitcast.1351, f32[96]{0} %bitcast.1353), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:41.089085: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[8,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,28,20]{3,2,1,0} %bitcast.1418, f32[256,128,3,3]{3,2,1,0} %bitcast.1425, f32[256]{0} %bitcast.1427), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:41.235434: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[8,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,56,40]{3,2,1,0} %bitcast.1496, f32[128,128,3,3]{3,2,1,0} %bitcast.1503, f32[128]{0} %bitcast.1505), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:41.512508: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.46 = (f32[8,48,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,96,112,80]{3,2,1,0} %bitcast.1574, f32[48,96,3,3]{3,2,1,0} %bitcast.1581, f32[48]{0} %bitcast.1583), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:41.995450: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.47 = (f32[8,24,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,48,112,80]{3,2,1,0} %bitcast.1610, f32[24,48,3,3]{3,2,1,0} %bitcast.1617, f32[24]{0} %bitcast.1619), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:42.274846: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.48 = (f32[8,8,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,24,112,80]{3,2,1,0} %bitcast.1646, f32[8,24,3,3]{3,2,1,0} %bitcast.1653, f32[8]{0} %bitcast.1655), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:42.915427: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[12,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[12,12,58,42]{3,2,1,0} %bitcast.1223, f32[24,12,3,3]{3,2,1,0} %bitcast.1230, f32[24]{0} %bitcast.1232), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:43.236351: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[3,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[3,96,56,40]{3,2,1,0} %bitcast.1344, f32[96,96,3,3]{3,2,1,0} %bitcast.1351, f32[96]{0} %bitcast.1353), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:43.461396: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[3,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[3,128,28,20]{3,2,1,0} %bitcast.1418, f32[256,128,3,3]{3,2,1,0} %bitcast.1425, f32[256]{0} %bitcast.1427), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 20:42:44.177210: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[3,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[3,128,56,40]{3,2,1,0} %bitcast.1496, f32[128,128,3,3]{3,2,1,0} %bitcast.1503, f32[128]{0} %bitcast.1505), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 65s 80ms/step - loss: 0.0184 - val_loss: 0.0039
# Epoch 2/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 3/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 4/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 5/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 28s 47ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 6/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 7/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 8/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 28s 46ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 9/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 10/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 11/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 12/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 27s 45ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 13/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s -25505us/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 14/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 15/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 26s -24005us/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 16/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 17/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 18/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 19/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 41ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 20/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 21/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 22/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 23/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 24/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 25/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 26/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 41ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 27/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 28/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 26s 44ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 29/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - loss: 0.0014 - val_loss: 9.4373e-04
# Epoch 30/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 31/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 32/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - loss: 0.0014 - val_loss: 9.4675e-04
# Epoch 33/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 34/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 35/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 36/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 37/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - loss: 0.0012 - val_loss: 9.2218e-04
# Epoch 38/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - loss: 0.0012 - val_loss: 9.8496e-04
# Epoch 39/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 40/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 41/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0012 - val_loss: 8.8769e-04
# Epoch 42/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 41ms/step - loss: 0.0011 - val_loss: 7.8896e-04
# Epoch 43/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 44/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0011 - val_loss: 9.5985e-04
# Epoch 45/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 9.9621e-04 - val_loss: 0.0010
# Epoch 46/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0010 - val_loss: 7.9834e-04
# Epoch 47/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0010 - val_loss: 8.3507e-04
# Epoch 48/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 49/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - loss: 0.0010 - val_loss: 8.4834e-04
# Epoch 50/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - loss: 9.8920e-04 - val_loss: 8.2766e-04

# %% [markdown]
# Судя по функции ошибки модель обучилась отлично: <br> MSE loss на тесте < $10^{-3}$ за ~20 мин. <br>  Переобучение не наблюдается.
#
# #### Ошибка на тесте меньше ошибки на тренировке. Как такое может быть?
#
# Такое происходит, когда какой-либо слой в модели ведет себя по-разному при тестировании и при обучении. Это слои типа Dropout и BatchNormalization.
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Слой BatchNormalization**»](https://colab.research.google.com/drive/1tT74848tqrvZuQ2InRrxTH6U1P9FvD-K))
#
# ---

# %% [markdown]
# ### Сохранение

# %% [markdown]
# Создадите папку для модели.

# %%
# Путь к папке для хранения моделей
PATH = 'my_ae_models'

# Создадим папку для моделей, если её еще нет
if not os.path.isdir(PATH):
  os.mkdir(PATH)

# %% [markdown]
# На первой практике вы сохранили веса модели. Это был первый способ сохранения результата. Второй способ – сохранить саму модель. Делается это через метод `ae_faces.save`. Загрузка через `tf.keras.models.load_model`

# %%
# Сохранение/восстановление всей модели
ae_faces.save(PATH + 'ae_faces.keras') # Сохраняем модель
ae_faces = load_model(PATH + 'ae_faces.keras') # Загружаем модель

# %% [markdown]
# ### Проверка результатов

# %% [markdown]
# Посмотрите, как НС предсказывает изображение. Сделайте предсказание на основе
# тренировочных данных и выведите изображения ниже.

# %%
# Получение предсказания автокодировщика на обучающей выборке
pred = ae_faces.predict(X_test)
# Out:
# 2025-05-19 21:12:16.052180: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[32,12,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,112,80]{3,2,1,0} %bitcast.1107, f32[12,1,3,3]{3,2,1,0} %bitcast.1114, f32[12]{0} %bitcast.1116), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:16.127744: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[128,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[128,12,58,42]{3,2,1,0} %bitcast.1155, f32[24,12,3,3]{3,2,1,0} %bitcast.1162, f32[24]{0} %bitcast.1164), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:17.338846: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[32,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,96,56,40]{3,2,1,0} %bitcast.1276, f32[96,96,3,3]{3,2,1,0} %bitcast.1283, f32[96]{0} %bitcast.1285), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:18.298818: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[32,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,28,20]{3,2,1,0} %bitcast.1350, f32[256,128,3,3]{3,2,1,0} %bitcast.1357, f32[256]{0} %bitcast.1359), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:19.326932: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[32,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,56,40]{3,2,1,0} %bitcast.1428, f32[128,128,3,3]{3,2,1,0} %bitcast.1435, f32[128]{0} %bitcast.1437), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:13:00.226794: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng25{k2=2,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[32,96,113,81]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,56,40]{3,2,1,0} %bitcast.1464, f32[128,96,3,3]{3,2,1,0} %bitcast.1471), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="functional_1/conv2d_transpose_1_2/conv_transpose" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:13:00.226998: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.969075315s
# Trying algorithm eng25{k2=2,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[32,96,113,81]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,56,40]{3,2,1,0} %bitcast.1464, f32[128,96,3,3]{3,2,1,0} %bitcast.1471), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="functional_1/conv2d_transpose_1_2/conv_transpose" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:12:20.502776: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.46 = (f32[32,48,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,96,112,80]{3,2,1,0} %bitcast.1506, f32[48,96,3,3]{3,2,1,0} %bitcast.1513, f32[48]{0} %bitcast.1515), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:22.179753: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.47 = (f32[32,24,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,48,112,80]{3,2,1,0} %bitcast.1542, f32[24,48,3,3]{3,2,1,0} %bitcast.1549, f32[24]{0} %bitcast.1551), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:22.926655: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.48 = (f32[32,8,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,24,112,80]{3,2,1,0} %bitcast.1578, f32[8,24,3,3]{3,2,1,0} %bitcast.1585, f32[8]{0} %bitcast.1587), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 2025-05-19 21:12:25.293009: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[27,12,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,1,112,80]{3,2,1,0} %bitcast.1107, f32[12,1,3,3]{3,2,1,0} %bitcast.1114, f32[12]{0} %bitcast.1116), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:25.364712: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.39 = (f32[108,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[108,12,58,42]{3,2,1,0} %bitcast.1155, f32[24,12,3,3]{3,2,1,0} %bitcast.1162, f32[24]{0} %bitcast.1164), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:13:05.227193: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=1,k4=3,k5=1,k6=0,k7=0,k19=0} for conv %cudnn-conv-bias-activation.39 = (f32[108,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[108,12,58,42]{3,2,1,0} %bitcast.1155, f32[24,12,3,3]{3,2,1,0} %bitcast.1162, f32[24]{0} %bitcast.1164), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:13:05.230543: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 39.826229569s
# Trying algorithm eng20{k2=1,k4=3,k5=1,k6=0,k7=0,k19=0} for conv %cudnn-conv-bias-activation.39 = (f32[108,24,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[108,12,58,42]{3,2,1,0} %bitcast.1155, f32[24,12,3,3]{3,2,1,0} %bitcast.1162, f32[24]{0} %bitcast.1164), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_1_2/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:12:25.892040: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.42 = (f32[27,96,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,96,56,40]{3,2,1,0} %bitcast.1276, f32[96,96,3,3]{3,2,1,0} %bitcast.1283, f32[96]{0} %bitcast.1285), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_4_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:26.769023: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.44 = (f32[27,256,28,20]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,128,28,20]{3,2,1,0} %bitcast.1350, f32[256,128,3,3]{3,2,1,0} %bitcast.1357, f32[256]{0} %bitcast.1359), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_6_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:28.081664: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.45 = (f32[27,128,56,40]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,128,56,40]{3,2,1,0} %bitcast.1428, f32[128,128,3,3]{3,2,1,0} %bitcast.1435, f32[128]{0} %bitcast.1437), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_7_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:13:10.231286: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=2} for conv %cudnn-conv-bw-input.5 = (f32[27,96,113,81]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,128,56,40]{3,2,1,0} %bitcast.1464, f32[128,96,3,3]{3,2,1,0} %bitcast.1471), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="functional_1/conv2d_transpose_1_2/conv_transpose" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:12:30.071633: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took -206.189461ms
# Trying algorithm eng4{k11=2} for conv %cudnn-conv-bw-input.5 = (f32[27,96,113,81]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,128,56,40]{3,2,1,0} %bitcast.1464, f32[128,96,3,3]{3,2,1,0} %bitcast.1471), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="functional_1/conv2d_transpose_1_2/conv_transpose" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-19 21:12:30.074382: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.46 = (f32[27,48,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,96,112,80]{3,2,1,0} %bitcast.1506, f32[48,96,3,3]{3,2,1,0} %bitcast.1513, f32[48]{0} %bitcast.1515), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_8_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:32.013670: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.47 = (f32[27,24,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,48,112,80]{3,2,1,0} %bitcast.1542, f32[24,48,3,3]{3,2,1,0} %bitcast.1549, f32[24]{0} %bitcast.1551), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_9_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-19 21:12:33.297479: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.48 = (f32[27,8,112,80]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,24,112,80]{3,2,1,0} %bitcast.1578, f32[8,24,3,3]{3,2,1,0} %bitcast.1585, f32[8]{0} %bitcast.1587), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1/conv2d_10_1/convolution" source_file="/home/viktor/.venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step

# %%
# Сравнение исходных и восстановленных картинок из обучающей выборки
plot_images(y_test, X_test, pred)

# %% [markdown]
# Видно, что изображения на выходе модели на вид очень похожы на оригинальные. Шум в значительной степени убран с изображений, сами лица восстановлены с большей частью деталей. Если приглядеться, можно увидеть небольшое размытие на предсказаниях.
# Некоторые детали (например, щетина) нейросеть распознала как шум и попыталась убрать.
#
# Если еще поэкспериментировать с моделью, то, возможно, получится добиться лучших результатов. Можно добавить больше слоев, поэкспериментировать с размерами ядер, разрежением ядер, каналами имеющихся слоев. Иными словами есть еще простор для усложнения модели за счет того, что переобучения нет. Либо, вероятно, наоборот – модель попроще даст лучший результат.
#
# Как видите, удаление шумов с изображения – не такая сложная задача, какой могла показаться. А что насчет мошеннических транзакций?

# %% [markdown]
# ## Определение мошеннических операций на датасете транзакций по кредитным картам

# %% [markdown]
# В данном разделе рассматривается решение задачи обнаружения мошеннических транзакций по кредитным картам.

# %% [markdown]
# ### Загрузка датасета и подготовка данных

# %% [markdown]
# Загрузите датасет по ссылке.

# %%
# Загрузка датасета из облака
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l13/creditcard.csv', None, quiet=True)
# Out:
# 'creditcard.csv'

# %% [markdown]
# Переведите его в массив данных и посмотрите содержимое.

# %%
# Чтение данных в таблицу
df = pd.read_csv("creditcard.csv")

# %%
# Вывод первых строк таблицы
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# *Признаки V1, V2, ... – значения функций преобразования [PCA](https://habr.com/ru/post/304214/). Исходные данные не предоставляются источником из соображений конфиденциальности.*
#
# Практически все данные уже готовы к работе с НС. Есть только два замечания: лишний
# столбец со временем и то, что нужно нормализовать данные в столбце «сумма».
#
# Удалите столбец *Time*.

# %%
data = df.drop(['Time'], axis=1)

# %% [markdown]
# Нормализуйте столбец *Amount*.

# %%
data['Amount'] = (data['Amount'] - data['Amount'].mean())/ data['Amount'].std()

# %% [markdown]
# Разделите на два отдельных датафрейма по признаку класса.

# %%
# Выделение данных нормальных и мошеннических операций
fraud_data = data[data.Class == 1]
normal_data = data[data.Class == 0]

# %% [markdown]
# Посмотрите размерность получившихся данных. Вышел огромный перевес в сторону
# нормальных операций. Соответственно, бинарная классификация не подходит.
# Используйте автокодировщик для поиска выбросов.

# %%
# Вывод формы полученных массивов
print(fraud_data.shape)
print(normal_data.shape)
# Out:
# (492, 30)
# (284315, 30)

# %% [markdown]
# Разделите нормальные данные в соотношении 0.8/0.2 на обучающую и тестовую выборки.

# %%
# Разбивка нормальных данных на обучающую и тестовую выборки
x_train, x_test = train_test_split(normal_data, test_size=0.2)

# %% [markdown]
# Завершите подготовку данных:
# * уберите столбец *Class* из набора тренировочных данных, так как в них только
# нормальные операции;
# * объедините тестовые выборки нормальных и мошеннических операций с помощью `pd.concat()`;
# * создайте набор данных с ответами для тестовой выборки. Возьмите данные из
# столбца *Class* тестовой выборки;
# * удалите столбец *Class* из тестовых данных;
# * преобразуйте все данные в Numpy-массивы.

# %%
# Удаление столбца класса из обучающей выборки
x_train = x_train.drop(['Class'], axis=1)
# Добавление всех мошеннических транзакций в тестовую выборку
x_test = pd.concat([x_test, fraud_data])
# Создание меток класса для тестовой выборки
y_test = x_test['Class']
# Удаление столбца класса из тестовой выборки
x_test = x_test.drop(['Class'], axis=1)
# Преобразование данных в массивы numpy
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# Проверьте, что все данные сходятся по размерности.

# %%
# Проверка формы полученных выборок
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (227452, 29)
# (57355, 29)
# (57355,)

# %% [markdown]
# ### Создание и обучение автокодировщика

# %% [markdown]
# Создайте простую и быструю в обучении НС из пары полносвязных слоев. Число признаков – 29. Размер латентного пространства должен быть меньше. Пусть это будет, например, 10.

# %%
# Функция создания автокодировщика для определения мошеннических транзакций
def create_credit_ae(in_parameters, latent_dim=10):
    # Вход
    input = Input(shape=(in_parameters,))

    # Полносвязные внутренний и финальный слои
    x = Dense(latent_dim, activation='relu')(input)
    output = Dense(in_parameters, activation='linear')(x)

    # Сборка и компиляция модели
    model = Model(inputs=input, outputs=output)
    model.compile(optimizer=Adam(0.0001), loss='mse')

    return model

# %%
# Создание автокодировщика
ae_credit = create_credit_ae(x_train.shape[1])

# %% [markdown]
# Обучите НС.

# %%
# Обучение автокодировщика, на входе и выходе - нормальные транзакции
history = ae_credit.fit(x_train, x_train,
                        epochs=50,
                        batch_size=32)
# Out:
# Epoch 1/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step - loss: 1.0526
# Epoch 2/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.6145
# Epoch 3/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.4522
# Epoch 4/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3982
# Epoch 5/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3731
# Epoch 6/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3668
# Epoch 7/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3609
# Epoch 8/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.3581
# Epoch 9/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.3543
# Epoch 10/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3578
# Epoch 11/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 49s 7ms/step - loss: 0.3558
# Epoch 12/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3535
# Epoch 13/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3524
# Epoch 14/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3567
# Epoch 15/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ -31s -4409us/step - loss: 0.3556
# Epoch 16/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3532
# Epoch 17/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3521
# Epoch 18/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s -4316us/step - loss: 0.3532
# Epoch 19/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3521
# Epoch 20/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3501
# Epoch 21/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3532
# Epoch 22/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3523
# Epoch 23/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3522
# Epoch 24/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3532
# Epoch 25/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3523
# Epoch 26/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3498
# Epoch 27/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step - loss: 0.3533
# Epoch 28/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3501
# Epoch 29/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3491
# Epoch 30/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3513
# Epoch 31/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3506
# Epoch 32/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3550
# Epoch 33/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3562
# Epoch 34/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3509
# Epoch 35/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3544
# Epoch 36/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3530
# Epoch 37/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3527
# Epoch 38/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3478
# Epoch 39/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3514
# Epoch 40/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 0.3514
# Epoch 41/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3499
# Epoch 42/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3483
# Epoch 43/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3513
# Epoch 44/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3513
# Epoch 45/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3519
# Epoch 46/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3497
# Epoch 47/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3481
# Epoch 48/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3513
# Epoch 49/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - loss: 0.3518
# Epoch 50/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 0.3527

# %% [markdown]
# Сохраните веса модели на вашем гугл-диске.

# %%
ae_credit.save_weights(PATH + 'ae_credit.weights.h5') # Сохраняем модель
ae_credit.load_weights(PATH + 'ae_credit.weights.h5') # Загружаем модель

# %%
# Вывод графика процесса обучения
plt.figure(figsize=(14,7))
plt.plot(history.history['loss'][10:],
         label='Ошибка на обучающем наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()

# %% [markdown]
# Как видно по графику, ошибка на обучающей выборке имеет скачкообразный характер, но тренд нисходящий.

# %% [markdown]
# ### Определение выбросов

# %% [markdown]
# Сделайте предсказание вашего автокодировщика на основе тестовой выборки.
#
# Подсчитайте ошибки на каждом наборе данных и выведите график, на котором отметьте оптимальный порог для отделения мошеннических операций (выбросов).

# %%
# Получение предсказания автокодировщика на тестовой выборке (нормальные + мошеннические транзакции)
pred_test = ae_credit.predict(x_test)
# Out:
# 1793/1793 ━━━━━━━━━━━━━━━━━━━━ 2s 979us/step

# %%
# Вычисление среднеквадратических ошибок на тестовой выборке
err_test = mean_squared_error(x_test.T,
                               pred_test.T,
                               multioutput='raw_values')

# Выделение ошибок на нормальных и мошеннических транзакциях
err_normal = err_test[y_test == 0]
err_fraud = err_test[y_test == 1]

# %%
print('Минимальная  ошибка нормальных транзакций: {:.5f}'.format(err_normal.min()))
print('Максимальная ошибка нормальных транзакций: {:.5f}'.format(err_normal.max()))
print('Средняя      ошибка нормальных транзакций: {:.5f}'.format(err_normal.mean()))
# Out:
# Минимальная  ошибка нормальных транзакций: 0.03679
# Максимальная ошибка нормальных транзакций: 328.79197
# Средняя      ошибка нормальных транзакций: 0.35753

# %%
print('Минимальная  ошибка мошеннических транзакций: {:.5f}'.format(err_fraud.min()))
print('Максимальная ошибка мошеннических транзакций: {:.5f}'.format(err_fraud.max()))
print('Средняя      ошибка мошеннических транзакций: {:.5f}'.format(err_fraud.mean()))
# Out:
# Минимальная  ошибка мошеннических транзакций: 0.15863
# Максимальная ошибка мошеннических транзакций: 95.76191
# Средняя      ошибка мошеннических транзакций: 18.86549

# %%
# Определение оптимального порога для нормальных и мошеннических транзакций
_, threshold, _, _, _ = find_optimal_threshold(err_normal, err_fraud, factor=0.1)
# Out:
# Оптимальный порог: 1.4969
# Распознано как норма на верных данных: 98.89%
# Распознано как норма на выбросах     : 14.43%
# Суммарная ошибка: 15.54%

# %%
# Вычисление доли верно распознанных нормальных и мошеннических транзакций
found_normal = (err_normal < threshold).mean()
found_fraud = (err_fraud >= threshold).mean()

# Вывод статистик
print('Распознано    нормальных транзакций: {:.2f}%'.format(100. * found_normal))
print('Распознано мошеннических транзакций: {:.2f}%'.format(100. * found_fraud))
print('Средняя точность распознавания     : {:.2f}%'.format(50. * (found_normal + found_fraud)))
# Out:
# Распознано    нормальных транзакций: 98.89%
# Распознано мошеннических транзакций: 85.57%
# Средняя точность распознавания     : 92.23%

# %% [markdown]
# Итак, создана и обучена модель автокодировщика с целью отделения мошеннических от нормальных транзакций. В целом задача решена успешно – средняя точность распознавания ~92%. В этой задаче была взята максимально простая модель, что оставляет большое пространство для экспериментов. Поэтому при желании вы можете попробовать усложнить архитектуру для получения лучшего результата.

# %% [markdown]
# ## Важно: о точности распознавания выбросов

# %% [markdown]
# В реальных задачах точность распознавания выбросов, например мошеннических
# транзакций, может по важности превалировать над точностью распознавания нормальных
# данных. В таком случае при определении оптимального порога и статистик используйте
# взвешенное, а не простое среднее этих двух параметров точности. Веса зададут меру
# важности параметров точности относительно друг друга. Значения весов подбирайте
# исходя из конкретного случая.

# %% [markdown]
# ## Итог

# %% [markdown]
# Итак, вы прошли вторую практику по теме **Автокодировщики**.
# <br> На этой практике вы:
# * закрепили знания, полученные в предыдущей практике и в теории;
# * научились чистить изображения от шума;
# * научились определять мошеннические транзакции в условиях сильного дисбаланса классов;
#
# На этом завершается тема **Автокодировщики**. Поздравляем с прохождением!

# %% [markdown]
# Теперь вы полностью готовы к решению домашнего задания. Но прежде, чем выполнять ДЗ сложности **Lite и выше**, советуем опробовать свои силы на примерах из задачника.
#
# ---
# [УИИ **Задачник** к теме «Архитектура автокодировщика»](https://colab.research.google.com/drive/1u6GP8ZpcP_nSYrJ_b0YfnVXlDtaaoVaT)
#
# ---

# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1mgQaPN1eqhzNpTYTqbbXZHmolI7d2yll?usp=sharing)
#
# 2. [Практика 1](https://colab.research.google.com/drive/1dApswu6lfXEWfPl9ZgTspfFIneWGQIOq?usp=sharing)
#
# 3. Практика 2
